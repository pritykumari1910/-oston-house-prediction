# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston
boston = load_boston()
# Out:
# C:\Users\prity\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
boston
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
print(boston['filename'])
# Out:
# boston_house_prices.csv

# %%
print(boston['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %%
print(boston['feature_names'])
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %%
print(boston['data'])
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 1.5300e+01 3.9690e+02 4.9800e+00]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9690e+02 9.1400e+00]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 1.7800e+01 3.9283e+02 4.0300e+00]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 5.6400e+00]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9345e+02 6.4800e+00]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 2.1000e+01 3.9690e+02 7.8800e+00]]

# %%
print(boston['target'])
# Out:
# [24.  21.6 34.7 33.4 36.2 28.7 22.9 27.1 16.5 18.9 15.  18.9 21.7 20.4
#  18.2 19.9 23.1 17.5 20.2 18.2 13.6 19.6 15.2 14.5 15.6 13.9 16.6 14.8
#  18.4 21.  12.7 14.5 13.2 13.1 13.5 18.9 20.  21.  24.7 30.8 34.9 26.6
#  25.3 24.7 21.2 19.3 20.  16.6 14.4 19.4 19.7 20.5 25.  23.4 18.9 35.4
#  24.7 31.6 23.3 19.6 18.7 16.  22.2 25.  33.  23.5 19.4 22.  17.4 20.9
#  24.2 21.7 22.8 23.4 24.1 21.4 20.  20.8 21.2 20.3 28.  23.9 24.8 22.9
#  23.9 26.6 22.5 22.2 23.6 28.7 22.6 22.  22.9 25.  20.6 28.4 21.4 38.7
#  43.8 33.2 27.5 26.5 18.6 19.3 20.1 19.5 19.5 20.4 19.8 19.4 21.7 22.8
#  18.8 18.7 18.5 18.3 21.2 19.2 20.4 19.3 22.  20.3 20.5 17.3 18.8 21.4
#  15.7 16.2 18.  14.3 19.2 19.6 23.  18.4 15.6 18.1 17.4 17.1 13.3 17.8
#  14.  14.4 13.4 15.6 11.8 13.8 15.6 14.6 17.8 15.4 21.5 19.6 15.3 19.4
#  17.  15.6 13.1 41.3 24.3 23.3 27.  50.  50.  50.  22.7 25.  50.  23.8
#  23.8 22.3 17.4 19.1 23.1 23.6 22.6 29.4 23.2 24.6 29.9 37.2 39.8 36.2
# ...

# %%
df = pd.DataFrame(boston['data'], columns = boston['feature_names'])
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
df['target'] = boston['target']
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %%
X = boston['data']
y = boston['target']

# %%
# A real-world dataset contains features that vary in magnitudes, units, and range. 
# It is better to perform normalization when the scale of a feature is irrelevant or misleading.
# Feature Scaling basically helps to normalize the data within a particular range. 
# Normally, several common class types contain the feature scaling function so that they make feature scaling automatically. 

# Scaling can be done by using StandardScalar.

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# X_scaled = sc.fit_transform(X)
# # y_scaled = sc.fit_transform(y)   # ValueError: Expected 2D array, got 1D array instead.
# # Reshape your data either using array.reshape(-1, 1) if your data has a single feature 
# # or array.reshape(1, -1) if it contains a single sample.
# y_scaled = sc.fit_transform(y.reshape(1, -1))

# %%
# X_scaled

# %%
# y_scaled

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 100)

# %%
print(len(X))
print(len(X_train))
print(len(X_test))
print(len(y_train))
print(len(y_test))
# Out:
# 506
# 303
# 203
# 303
# 203

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=5000)

# %% [markdown]
# # Applying Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
y_pred = model_lr.predict(X_test)
print(y_pred)
# Out:
# [33.53764389 31.83293263 22.58006382 17.70392882 20.58138034 26.23903581
#  25.81396369 24.10938258 21.7654968  18.9553138  26.38568258 16.4045568
#  20.76170822 13.67959318 41.11851762 19.03335692 28.02779429 19.68395425
#  31.64197435 40.16721807 35.45373873 19.61103339 20.0957707  17.31320386
#  13.72534699 11.78992891 26.77034423 19.31858582 18.2767362  20.2090713
#  15.26966099 24.54236741 39.21716391 25.02074039 32.18664935 28.82829704
#  16.06687883 15.29555155 15.59605718 23.66750185 23.11710662 23.99082055
#  13.01076932 21.28718984 30.99543849 27.19016811 18.32200259 16.71894822
#  16.76183674 12.24883105 20.96644486 19.72072348 23.66460092 24.08207501
#  11.31357386 14.64251709 24.94171789 33.66673518  9.86444912 20.77640328
#  16.81671641 18.99150007 18.5719214  29.87021379 21.6400528  25.98965904
#  15.57572902 24.50092523 23.14127678 20.51390313 18.46427483 23.22900779
#   4.37182441 16.11299217 29.20841756  9.14068924 25.87624023 35.17458767
# ...

# %%
details = {
    'y_test' : list(y_test),
    'y_pred' : list(y_pred),
}
temp = pd.DataFrame(details)
temp
# Out:
#      y_test     y_pred
# 0      34.6  33.537644
# 1      31.5  31.832933
# 2      20.6  22.580064
# 3      14.5  17.703929
# 4      16.2  20.581380
# ..      ...        ...
# 198    50.0  31.553081
# 199    16.4  18.210345
# 200    20.0  16.336688
# 201    15.2  10.126607
# 202    22.2  22.916134
#
# [203 rows x 2 columns]

# %% [markdown]
# # Finding Error between Actual House Prices and Predicted House Prices

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  3.556609882768382
# Mean Squared Error =  28.815499115032463
# Root Mean Squared Error =  5.368006996552116

# %% [markdown]
# # Plotting Scatter Plot

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
plt.title("Prices vs Predicted prices")
plt.show()

# %% [markdown]
# # Histogram

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(y_test - y_test)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
import seaborn as sns
sns.histplot(y_pred - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Run 'pip install xgboost' command on Anaconda Prompt 
# OR run '!pip install xgboost' in Jupyter Notebook cell
# !pip install xgboost

# %%
#import xgboost
from xgboost import XGBRegressor
xgboostRegressor = XGBRegressor()
xgboostRegressor.fit(X_train, y_train)
y_pred = xgboostRegressor.predict(X_test)
print(y_pred)
# Out:
# [31.540113  32.31122   16.855307  20.180107  19.886408  23.474
#  22.64789   23.485243  20.973278  16.433739  23.78212   14.011601
#  21.815308  16.87565   48.673065  26.308052  24.950552  22.486643
#  27.695995  49.25008   34.388783  12.710819  18.345327  16.166449
#   8.754769  14.919612  26.215998  16.4014    17.819506  17.942705
#  17.817493  21.4777    42.014957  23.586775  29.30789   33.19867
#  17.371368   7.6693077 14.849432  22.514885  20.348978  20.882648
#  14.615213  22.895586  24.860155  23.245028  19.647003  15.944858
#  14.428588  13.513496  20.347143  21.73231   21.940294  27.447786
#  13.66613   16.238787  31.614414  32.42985    9.798489  20.134758
#  12.621885  15.2860365 17.049847  31.239204  20.442188  26.76114
#  17.6146    33.800854  21.622507  20.789108  13.275672  18.166048
#   9.886433  15.565616  30.812899   7.8704333 25.015429  43.062008
#  11.356133  22.367374  45.990368  46.58089   13.970459  14.36874
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  2.3938867836750197
# Mean Squared Error =  13.947051921227159
# Root Mean Squared Error =  3.7345751995678382

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
 xgboostRegressor.predict([list(X_test[0])])
# Out:
# array([31.540113], dtype=float32)

# %%
list(X_test)
test_data = []
for i in range(len(X_test)):
    test_data.append([list(X_test[i])])
test_data
# Out:
# [[[0.03768,
#    80.0,
#    1.52,
#    0.0,
#    0.404,
#    7.274,
#    38.3,
#    7.309,
#    2.0,
#    329.0,
#    12.6,
#    392.2,
#    6.62]],
#  [[0.44178,
#    0.0,
#    6.2,
#    0.0,
#    0.504,
#    6.552,
#    21.4,
#    3.3751,
#    8.0,
#    307.0,
#    17.4,
#    380.34,
#    3.76]],
#  [[0.04527,
#    0.0,
#    11.93,
#    0.0,
#    0.573,
#    6.12,
#    76.7,
#    2.2875,
#    1.0,
#    273.0,
#    21.0,
#    396.9,
#    9.08]],
#  [[1.35472,
#    0.0,
#    8.14,
#    0.0,
#    0.538,
#    6.072,
#    100.0,
#    4.175,
#    4.0,
#    307.0,
#    21.0,
#    376.73,
#    13.04]],
#  [[0.25356,
#    0.0,
#    9.9,
#    0.0,
#    0.544,
#    5.705,
#    77.7,
#    3.945,
#    4.0,
#    304.0,
#    18.4,
#    396.42,
#    11.5]],
#  [[2.44953,
#    0.0,
#    19.58,
#    0.0,
#    0.605,
#    6.402,
#    95.2,
#    2.2625,
#    5.0,
#    403.0,
#    14.7,
#    330.04,
#    11.32]],
#  [[0.10084,
#    0.0,
#    10.01,
#    0.0,
#    0.547,
#    6.715,
#    81.6,
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
randomForestRegressor = RandomForestRegressor()
# randomForestRegressor = RandomForestRegressor(random_state = 50)
randomForestRegressor.fit(X_train, y_train)
y_pred = randomForestRegressor.predict(X_test)
print(y_pred)
# Out:
# [33.704 27.612 17.318 19.75  20.132 22.868 24.855 22.02  20.47  16.002
#  23.759 13.931 23.793 19.574 47.213 25.904 23.871 21.611 29.942 46.535
#  32.721 14.749 18.999 16.067  9.808 14.131 26.984 15.371 16.157 19.426
#  17.331 20.859 43.731 24.18  25.855 33.171 21.12  14.521 14.178 21.057
#  20.217 22.451 14.904 21.013 24.759 24.736 18.149 14.297 13.848 14.012
#  19.596 19.859 22.153 26.159 13.392 17.472 29.685 32.603 10.268 20.584
#  13.765 16.343 16.692 33.36  20.949 23.634 17.32  31.354 23.439 21.035
#  13.17  17.715  8.557 15.418 31.142  9.389 24.776 44.191 11.515 21.61
#  45.008 44.26  14.812 14.112 14.287 14.017 20.169 22.017 12.599 19.529
#  27.534 22.189 20.874 23.89  17.571 17.288 27.66  47.067 10.174 31.835
#  15.933 12.78  13.124 24.082 32.077 19.474 23.13  12.655 15.522 28.782
#  24.683 32.757 35.147 12.454 21.23  20.28  25.337 19.757 23.809  7.466
#  14.316 15.925 21.116 24.081 19.688 14.636 21.183 17.945 21.062 20.936
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  2.6191921182265996
# Mean Squared Error =  17.969284551724122
# Root Mean Squared Error =  4.239019291265861

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# # Support Vector Regressor (SVR)
# ## SVR kernel : {'linear', 'poly', 'rbf', 'sigmoid', etc.}
# Default kernel = 'rbf'

# %%
from sklearn.svm import SVR
supportVectorRegressor = SVR(kernel = 'rbf')
supportVectorRegressor.fit(X_train, y_train)
y_pred = supportVectorRegressor.predict(X_test)
print(y_pred)
# Out:
# [23.45443701 23.24949738 23.38050065 22.12938398 22.68959596 19.44516419
#  19.71090447 23.58066681 20.58258568 14.933371   24.09494328 15.69980737
#  22.34302774 20.06247679 25.71815062 21.19458226 22.70276754 22.73498865
#  23.08392484 20.16015649 23.70059145 15.67901157 19.16756025 14.99512031
#  15.65274691 13.49374074 24.58686134 15.74723291 16.1446074  23.66228311
#  19.27552383 22.59053302 22.48005392 23.42467552 23.55118319 24.78769421
#  13.42864471 13.51579171 15.08365542 23.71752137 22.80899942 23.43263786
#  13.51233681 20.38145274 19.62599548 23.34812532 15.8719983  19.61906734
#  15.68299923 13.54869512 23.98820564 20.69681913 24.36665236 23.12712809
#  15.18620529 20.69465563 23.20346946 25.29642079 13.41467801 20.74272513
#  13.54044198 13.80155134 18.5661796  23.90185525 24.85486702 23.75621964
#  19.17719754 26.14330037 24.63005545 22.51261206 15.66066006 22.37023474
#  14.60518233 22.3895609  24.95151158 13.38164727 24.97224927 23.38868324
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  5.661513602407835
# Mean Squared Error =  78.62739623847672
# Root Mean Squared Error =  8.86720904447824

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.svm import SVR
supportVectorRegressor = SVR(kernel = 'sigmoid')
supportVectorRegressor.fit(X_train, y_train)
y_pred = supportVectorRegressor.predict(X_test)
print(y_pred)
# Out:
# [21.91244718 21.61656273 22.10522282 21.28215899 21.75937354 19.83297038
#  21.23955015 22.10324322 21.25240155 20.84466611 22.25366218 22.25024754
#  21.39254883 21.57592614 23.42860814 21.04467256 21.26296797 20.98468929
#  21.18776195 21.09087365 22.21301309 22.27891712 20.05394903 20.86851279
#  22.19427407 12.10027744 22.43163751 22.27964652 22.28323079 22.01546991
#  21.08011912 21.41415541 21.45075062 22.03274807 22.03297165 23.01022784
#  11.80268128 12.39925376 21.09230942 22.16324524 21.7647537  22.04214643
#  12.52336827 21.05771423 20.043671   21.93398566 22.21804373 20.30293775
#  21.79298723 11.84217908 22.14355804 21.25342309 22.62656327 21.76472464
#  21.4405451  21.30080003 21.65575868 22.96635897 11.98886052 21.12159492
#  14.64220625 17.5294973  18.18496719 22.19424553 23.04857638 22.01478259
#  20.86895305 24.08919053 23.28349268 21.63853611 22.28988197 21.65437746
#  20.13830356 21.69068955 22.84461384 12.048558   22.97414875 22.08781545
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  6.317327564144703
# Mean Squared Error =  85.46996540688619
# Root Mean Squared Error =  9.244996777007886

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.svm import SVR
supportVectorRegressor = SVR(kernel = 'linear')
supportVectorRegressor.fit(X_train, y_train)
y_pred = supportVectorRegressor.predict(X_test)
print(y_pred)
# Out:
# [32.08594106 29.92807136 22.53425486 18.16123801 19.78821354 24.09730882
#  25.00992767 23.42404177 21.54917204 18.74389782 25.06655508 15.90506411
#  21.69863474 14.93655582 39.15726903 20.68742555 26.46503584 17.68886605
#  30.05427944 38.96763643 33.8920009  20.30502668 18.70554379 16.82771696
#  14.19913938 10.58483183 26.83030381 18.76880187 16.95898556 19.59541728
#  15.84505647 22.70642458 38.59813455 24.65635246 30.80226084 28.869852
#  12.60115724 13.60561302 14.38043006 22.65223028 22.04601615 24.45210196
#  11.21885211 20.3475841  27.93429831 25.68092973 17.54785571 17.27772074
#  15.74085664 11.00135885 20.83544309 19.49518684 22.68146565 24.63935809
#  10.07488591 14.46740266 26.0137235  32.77793002  8.33029851 20.00975004
#  14.46812232 17.41432982 18.50588555 29.72308111 22.14887627 25.0687331
#  16.0902767  25.68069762 21.85992739 19.96175549 18.44605227 21.70254558
#   3.23331367 17.02320563 28.66239839  8.59598833 25.09954928 34.61298635
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  3.475375620248327
# Mean Squared Error =  31.73837957826227
# Root Mean Squared Error =  5.633682594738744

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.svm import SVR
supportVectorRegressor = SVR(kernel = 'poly')
supportVectorRegressor.fit(X_train, y_train)
y_pred = supportVectorRegressor.predict(X_test)
print(y_pred)
# Out:
# [23.9368102  23.21813279 22.33412103 21.41690595 22.10069922 20.21574
#  20.82519452 22.75403207 20.88044927 14.21577064 23.84185354 15.12005406
#  21.73049483 22.78014256 24.28687986 23.11516788 23.83175234 22.47923819
#  23.43690936 20.8172078  22.50379504 14.06534525 20.48649626 14.50598025
#  14.92168552 13.53193377 24.1542183  15.31642519 17.39425344 23.54898202
#  20.09156011 22.1421423  21.95343685 22.79246849 22.31363122 23.14213652
#  12.79526453 13.53843547 14.50966166 23.01911751 22.44880165 22.43145034
#  13.69392014 22.44567961 20.44038209 22.75339866 16.16270646 20.18501228
#  16.07130213 13.74835421 24.36535365 21.12564601 22.94520503 23.64200062
#  14.24081286 21.35038625 23.81750415 24.43316236 13.07419048 21.86638724
#  13.70292956 13.29492188 19.78085455 23.29268117 23.28175539 23.06346217
#  20.0291793  24.03973827 22.37749433 23.11209325 14.74445065 21.65138514
#  13.80205251 21.67225035 23.66477511 12.90339538 23.68689883 22.42236076
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  5.537660183692249
# Mean Squared Error =  78.60178102502114
# Root Mean Squared Error =  8.865764548250825

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
from sklearn.neural_network import MLPRegressor
MLPRegressor = MLPRegressor(random_state = 1, max_iter = 10000).fit(X_train, y_train)
y_pred = MLPRegressor.predict(X_test)
print(y_pred)
# Out:
# [28.3142005  34.15861846 19.70361665 19.72734632 19.04327547 22.30297604
#  22.48152882 19.87978384 22.22142483 17.16338576 25.20766862 15.25635583
#  19.33694937 21.92480581 42.56559451 23.80420371 28.30051773 18.65830637
#  23.3019404  45.21646123 31.69082585 20.45837772 14.76885618 15.35458037
#   9.79175159 12.55345863 28.46923476 15.79833325 15.4884704  19.92583136
#  16.63046261 20.12966079 39.29420744 22.74871999 25.00638532 33.0535392
#  16.40891817 10.18458581 14.23214434 22.42548732 18.73289592 19.12262322
#  12.54006875 19.52354002 32.40355605 21.2504125  17.26720382 16.26757019
#  11.97900353 11.96116461 23.1108607  18.8539495  23.01977174 27.47650332
#  10.22017194 18.25687098 31.8356583  38.30227165 10.5349876  18.0421766
#  13.17698865 17.12392109 16.39400861 26.79163338 24.2898417  22.0293992
#  15.69158141 34.53731698 21.38697023 23.19170566 12.46841102 21.84214561
#   7.79247464 16.90890089 29.04103404 10.78308487 26.42688727 34.62672406
# ...

# %%
from sklearn import metrics
print('Mean Absolute Error = ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error = ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error = ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error =  3.275337726598202
# Mean Squared Error =  21.63148838995841
# Root Mean Squared Error =  4.650966393122875

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices v/s Predicted Prices")
plt.show()

# %%
import seaborn as sns
sns.histplot(y_test - y_pred)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# ...

# %% [markdown]
# # Select the best regression algorithm based on MAE, MSE and RMSE.
# # Get predictions corresponding to the data inserted by the user

# %%
xgboostRegressor.predict([[0.04741, 0.0, 11.93, 0.0, 0.573, 6.030, 80.8, 2.5050, 1.0, 273.0, 21.0, 396.90]])
# Out:
# array([25.948862], dtype=float32)

# %%
xgboostRegressor.predict([[0.01524, 12.5, 20.3, 0.0, 0.5486, 6.030, 80.8, 2.5050, 1.0, 273.0, 21.0, 396.90]])
# Out:
# array([25.964422], dtype=float32)
